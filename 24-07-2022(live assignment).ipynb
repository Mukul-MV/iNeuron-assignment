# %%
Mysql : 
    
    1. Create a  table attribute dataset and dress dataset
    2. Do a bulk load for these two table for respective dataset 
    3. read these dataset in pandas as a dataframe 
    4. Convert attribute dataset in json format 
    5. Store this dataset into mongodb
    6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
    7. Write a sql query to find out how many unique dress that we have based on dress id 
    8. Try to find out how many dress is having recommendation 0
    9. Try to find out total dress sell for individual dress id 
    10. Try to find out a third highest most selling dress id

# %% [markdown]
# **Questions**

# %% [markdown]
# **3. read these dataset in pandas as a dataframe**

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='127.0.0.1', database='fashion', user='root', password='12345')

# %%
df_attribute = pd.read_sql("select * from attribute",con=db_connection)

# %%
df_attribute
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %%
df_dress = pd.read_sql("select * from dress",con=db_connection)

# %%
df_dress
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 493   713391965          0          0         0       560       554       544
# 494   722565148          0          0         0       875       866       861
# 495   532874347          0          0         0       734       728       726
# 496   655464934          0          0         0       254       259       261
# 497   919930954          0          0         0       538       545       558
#
# ...

# %% [markdown]
# **4. Convert attribute dataset in json format**

# %%
df_attribute.to_json(r"D:\\INEURONE\\assigment\\Live\\test1.json")

# %%
js = pd.read_json("D:\\INEURONE\\assigment\\Live\\test1.json")

# %%
js
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %% [markdown]
# **5. Store this dataset into mongodb**

# %%
import pymongo

client = pymongo.MongoClient("mongodb://mukulvyas:{pswrd}@cluster-shard-00-00.kkjvo.mongodb.net:27017,cluster-shard-00-01.kkjvo.mongodb.net:27017,cluster-shard-00-02.kkjvo.mongodb.net:27017/?ssl=true&replicaSet=atlas-ag81y5-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

database = client["fashion"]
collection = database["attribute"]

collection.insert_many(df_attribute.to_dict("records")) #5. Store this dataset into mongodb

# %% [markdown]
# **6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID**

# %%
pd.read_sql("select * from attribute a left join dress d  on a.dress_id=d.dress_id",con=db_connection)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 545   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 546   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 547   532874347   Casual  Average     4.7     M  Summer     v-neck
# 548   655464934   Casual  Average     4.6     L  winter  boat-neck
# 549   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  ... 24/9/2013 26/9/2013 28/9/2013  \
# 0      sleevless    empire           None  ...    3554.0    3624.0    3706.0
# ...

# %% [markdown]
# **7. Write a sql query to find out how many unique dress that we have based on dress id**

# %%
pd.read_sql("select count(distinct(dress_id)) as all_unique_dresses from attribute",con=db_connection)
# Out:
#    all_unique_dresses
# 0                 475

# %% [markdown]
# **8. Try to find out how many dress is having recommendation 0**

# %%
pd.read_sql("select count(*) as all_ZEROS_Recommendation from attribute where Recommendation = 0",con=db_connection)
# Out:
#    all_ZEROS_Recommendation
# 0                       290

# %% [markdown]
# **9. Try to find out total dress sell for individual dress id**

# %%
df_dress
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 493   713391965          0          0         0       560       554       544
# 494   722565148          0          0         0       875       866       861
# 495   532874347          0          0         0       734       728       726
# 496   655464934          0          0         0       254       259       261
# 497   919930954          0          0         0       538       545       558
#
# ...

# %%
df_dress.set_index("Dress_ID",inplace = True)
df_dress
# Out:
#             29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# Dress_ID
# 1006032852       2114       2274      2491      2660      2727      2887
# 1212192089        151        275       570       750       813      1066
# 1190380701          6          7         7         7         8         8
# 966005983        1005       1128      1326      1455      1507      1621
# 876339541         996       1175      1304      1396      1432      1559
# ...               ...        ...       ...       ...       ...       ...
# 713391965           0          0         0       560       554       544
# 722565148           0          0         0       875       866       861
# 532874347           0          0         0       734       728       726
# 655464934           0          0         0       254       259       261
# 919930954           0          0         0       538       545       558
#
#             10/9/2013  12/9/2013  14/9/2013  16/9/2013  ...  24/9/2013  \
# ...

# %%
df_dress["Total_sales"] = df_dress.sum(axis=1)
df_dress[["Total_sales"]]
# Out:
#             Total_sales
# Dress_ID
# 1006032852        75979
# 1212192089        52256
# 1190380701          223
# 966005983         39691
# 876339541         44077
# ...                 ...
# 713391965          8915
# 722565148         17508
# 532874347         12606
# 655464934          5167
# 919930954         12312
#
# [498 rows x 1 columns]

# %% [markdown]
# **10. Try to find out a third highest most selling dress id**

# %%
df_dress[["Total_sales"]].nlargest(3,"Total_sales")
# Out:
#             Total_sales
# Dress_ID
# 629131530        155927
# 735635595         91556
# 1006032852        75979

# %%
print("3rd highest sold dress")
df_dress[["Total_sales"]][0:1].nlargest(3,"Total_sales")
# Out:
# 3rd highest sold dress
#             Total_sales
# Dress_ID
# 1006032852        75979
